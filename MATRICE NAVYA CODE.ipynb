# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\hp\anaconda3\lib\site-packages (24.3.1)

# %%
import sys
# !{sys.executable} -m pip install numpy opencv-python matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import sys
# !{sys.executable} -m pip install opencv-python matplotlib albumentations
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: albumentations in c:\users\hp\appdata\roaming\python\python310\site-packages (1.4.21)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hp\anaconda3\lib\site-packages (from albumentations) (1.13.0)
# Requirement already satisfied: PyYAML in c:\users\hp\anaconda3\lib\site-packages (from albumentations) (6.0.1)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from albumentations) (2.10.1)
# Requirement already satisfied: albucore==0.0.20 in c:\users\hp\appdata\roaming\python\python310\site-packages (from albumentations) (0.0.20)
# Requirement already satisfied: eval-type-backport in c:\users\hp\anaconda3\lib\site-packages (from albumentations) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\hp\appdata\roaming\python\python310\site-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\hp\anaconda3\lib\site-packages (from albucore==0.0.20->albumentations) (3.10.10)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\hp\anaconda3\lib\site-packages (from albucore==0.0.20->albumentations) (6.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from dataset_utils import random_perspective, augment_hsv, cutout, load_mosaic, mixup, letterbox

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from dataset_utils import random_perspective, augment_hsv, cutout, load_mosaic, mixup, letterbox

# Load the image
image_path = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\images\Arborio-1-_jpg.rf.4158416ae1b61f8061c42300ca5b8094.jpg"
label_path = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\labels\Arborio-1-_jpg.rf.4158416ae1b61f8061c42300ca5b8094.txt"

image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB for visualization

# Load the label (polygon-like format)
with open(label_path, 'r') as f:
    data = f.read().strip().split()
polygon_points = np.array(data[1:], dtype=np.float32).reshape(-1, 2)  # Reshape to (N, 2)

# Scale the label points to the image dimensions
polygon_points[:, 0] *= image.shape[1]  # Scale x-coordinates
polygon_points[:, 1] *= image.shape[0]  # Scale y-coordinates

# Function to draw polygons on the image
def draw_polygon(img, points, color=(255, 0, 0)):
    img_copy = img.copy()
    points = points.astype(int)
    for i in range(len(points)):
        cv2.line(img_copy, tuple(points[i]), tuple(points[(i + 1) % len(points)]), color, 2)
    return img_copy

# Augmentation Visualizations
# 1. Original Image with Polygon
original_with_polygon = draw_polygon(image, polygon_points)

# 2. Random Perspective
perspective_image, perspective_labels = random_perspective(image, polygon_points)
perspective_with_polygon = draw_polygon(perspective_image, perspective_labels)

# 3. HSV Augmentation
hsv_image = augment_hsv(image)

# 4. Cutout Augmentation
cutout_image, _ = cutout(image, polygon_points)

# 5. Mixup (requires two images; using the same image twice for simplicity)
mixup_image, mixup_labels = mixup(image, polygon_points, image, polygon_points)
mixup_with_polygon = draw_polygon(mixup_image, mixup_labels)

# 6. Mosaic Augmentation (requires 4 images; using the same image repeatedly for simplicity)
mosaic_images = [image] * 4  # Replace with 4 distinct images from your dataset for real use
mosaic_labels = [polygon_points] * 4  # Replace with corresponding labels
mosaic_image, mosaic_combined_labels = load_mosaic(mosaic_images, mosaic_labels, img_size=640)
mosaic_with_polygon = draw_polygon(mosaic_image, mosaic_combined_labels)

# 7. Letterbox Resize
letterbox_image = letterbox(image, new_shape=(640, 640))

# Display Results
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Original Image
axes[0, 0].imshow(original_with_polygon)
axes[0, 0].set_title("Original with Polygon")
axes[0, 0].axis("off")

# Random Perspective
axes[0, 1].imshow(perspective_with_polygon)
axes[0, 1].set_title("Random Perspective")
axes[0, 1].axis("off")

# HSV Augmentation
axes[0, 2].imshow(hsv_image)
axes[0, 2].set_title("HSV Augmentation")
axes[0, 2].axis("off")

# Cutout Augmentation
axes[1, 0].imshow(cutout_image)
axes[1, 0].set_title("Cutout Augmentation")
axes[1, 0].axis("off")

# Mixup Augmentation
axes[1, 1].imshow(mixup_with_polygon)
axes[1, 1].set_title("Mixup Augmentation")
axes[1, 1].axis("off")

# Mosaic Augmentation
axes[1, 2].imshow(mosaic_with_polygon)
axes[1, 2].set_title("Mosaic Augmentation")
axes[1, 2].axis("off")

# Letterbox Resize
axes[2, 0].imshow(letterbox_image)
axes[2, 0].set_title("Letterbox Resize")
axes[2, 0].axis("off")

# Turn off the last unused subplots
axes[2, 1].axis("off")
axes[2, 2].axis("off")

plt.tight_layout()
plt.show()

# %%
# Clone the YOLOv7 repository
# !git clone https://github.com/THU-MIG/yolov10

import os
os.chdir("yolov10")

# Install dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov7'...
# Updating files:  73% (79/108)
# Updating files:  74% (80/108)
# Updating files:  75% (81/108)
# Updating files:  76% (83/108)
# Updating files:  77% (84/108)
# Updating files:  78% (85/108)
# Updating files:  79% (86/108)
# Updating files:  80% (87/108)
# Updating files:  81% (88/108)
# Updating files:  82% (89/108)
# Updating files:  83% (90/108)
# Updating files:  84% (91/108)
# Updating files:  85% (92/108)
# Updating files:  86% (93/108)
# Updating files:  87% (94/108)
# Updating files:  88% (96/108)
# Updating files:  89% (97/108)
# Updating files:  90% (98/108)
# Updating files:  91% (99/108)
# Updating files:  92% (100/108)
# Updating files:  93% (101/108)
# Updating files:  94% (102/108)
# Updating files:  95% (103/108)
# Updating files:  96% (104/108)
# Updating files:  97% (105/108)
# Updating files:  98% (106/108)
# Updating files:  99% (107/108)
# Updating files: 100% (108/108)
# Updating files: 100% (108/108), done.
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.7.0)
# Collecting numpy<1.24.0,>=1.18.5 (from -r requirements.txt (line 5))
#   Downloading numpy-1.23.5-cp310-cp310-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (4.9.0.80)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (1.13.0)
# Requirement already satisfied: torch!=1.12.0,>=1.7.0 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: torchvision!=0.13.0,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (0.15.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (4.64.1)
# Collecting protobuf<4.21.3 (from -r requirements.txt (line 14))
#   Downloading protobuf-4.21.2-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Collecting tensorboard>=2.4.1 (from -r requirements.txt (line 17))
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 21)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 22)) (0.12.2)
# Requirement already satisfied: ipython in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 34)) (8.10.0)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 35)) (5.9.8)
# Requirement already satisfied: thop in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 36)) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (4.12.2)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.6)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->-r requirements.txt (line 17))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.4.1->-r requirements.txt (line 17))
#   Downloading grpcio-1.68.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (69.5.1)
# Requirement already satisfied: six>1.9 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->-r requirements.txt (line 17))
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2022.7)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\hp\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 34)) (5.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->-r requirements.txt (line 34)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.2.1)
# Downloading numpy-1.23.5-cp310-cp310-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.6 MB 1.9 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/14.6 MB 1.9 MB/s eta 0:00:08
#    --- ------------------------------------ 1.3/14.6 MB 1.5 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/14.6 MB 1.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/14.6 MB 1.4 MB/s eta 0:00:10
#    ----- ---------------------------------- 2.1/14.6 MB 1.4 MB/s eta 0:00:09
#    ------ --------------------------------- 2.4/14.6 MB 1.4 MB/s eta 0:00:09
#    ------- -------------------------------- 2.9/14.6 MB 1.5 MB/s eta 0:00:09
#    -------- ------------------------------- 3.1/14.6 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.7/14.6 MB 1.5 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.9/14.6 MB 1.6 MB/s eta 0:00:07
#    ------------ --------------------------- 4.5/14.6 MB 1.6 MB/s eta 0:00:07
#    ------------- -------------------------- 5.0/14.6 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 5.2/14.6 MB 1.6 MB/s eta 0:00:06
#    --------------- ------------------------ 5.8/14.6 MB 1.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 6.0/14.6 MB 1.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.6/14.6 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 6.8/14.6 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 7.3/14.6 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 7.9/14.6 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.1/14.6 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.4/14.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------ --------------- 8.9/14.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 9.4/14.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 9.7/14.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 10.0/14.6 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.5/14.6 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 11.0/14.6 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 11.3/14.6 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 11.8/14.6 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.6 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.6/14.6 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.8/14.6 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.1/14.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 1.6 MB/s eta 0:00:00
# Downloading protobuf-4.21.2-cp310-abi3-win_amd64.whl (524 kB)
#    ---------------------------------------- 0.0/525.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/525.0 kB ? eta -:--:--
#    ---------------------------------------  524.3/525.0 kB 1.9 MB/s eta 0:00:01
#    -------------------------------------- 525.0/525.0 kB 884.9 kB/s eta 0:00:00
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.9 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.5 MB 1.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.5 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 1.8/5.5 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.4/5.5 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.6/5.5 MB 1.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 3.4/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.2 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading grpcio-1.68.0-cp310-cp310-win_amd64.whl (4.4 MB)
#    ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.4 MB 2.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.0/4.4 MB 1.9 MB/s eta 0:00:02
#    -------------- ------------------------- 1.6/4.4 MB 1.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.8/4.4 MB 1.9 MB/s eta 0:00:02
#    --------------------- ------------------ 2.4/4.4 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.6/4.4 MB 1.8 MB/s eta 0:00:02
#    -------------------------- ------------- 2.9/4.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.1/4.4 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.7/4.4 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.9/4.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.4 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.4/4.4 MB 1.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorboard-data-server, protobuf, numpy, grpcio, absl-py, tensorboard
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed absl-py-2.1.0 grpcio-1.68.0 numpy-1.23.5 protobuf-4.21.2 tensorboard-2.18.0 tensorboard-data-server-0.7.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Hp\anaconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Hp\anaconda3\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# albucore 0.0.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.21 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.

# %%
import os
import numpy as np

def convert_polygon_to_bbox(label_line):
    """
    Transform a label line with polygon data into YOLO bounding box format.
    """
    # Split the line and extract numerical values
    values = list(map(float, label_line.strip().split()))
    class_id = int(values[0])  # The first value represents the class ID
    points = np.array(values[1:]).reshape(-1, 2)  # Convert the rest into pairs of (x, y)

    # Calculate the minimum and maximum coordinates
    x_min = points[:, 0].min()
    x_max = points[:, 0].max()
    y_min = points[:, 1].min()
    y_max = points[:, 1].max()

    # Derive YOLO bounding box format
    x_center = (x_min + x_max) / 2
    y_center = (y_min + y_max) / 2
    width = x_max - x_min
    height = y_max - y_min

    return [class_id, x_center, y_center, width, height]

def process_labels_in_place(input_dir):
    """
    Convert all label files in a directory from polygon format to YOLO bounding box format
    and update the files with the new format.
    
    Args:
    - input_dir (str): Path to the directory containing the label files.
    """
    for file_name in os.listdir(input_dir):
        if file_name.endswith(".txt"):  # Ensure only .txt files are processed
            file_path = os.path.join(input_dir, file_name)

            # Read the original label file
            with open(file_path, "r") as infile:
                label_lines = infile.readlines()

            # Process and overwrite the label file
            with open(file_path, "w") as outfile:
                for line in label_lines:
                    bbox = convert_polygon_to_bbox(line)
                    # Write in YOLO format: class_id x_center y_center width height
                    outfile.write(f"{bbox[0]} {bbox[1]:.6f} {bbox[2]:.6f} {bbox[3]:.6f} {bbox[4]:.6f}\n")

    print(f"Converted and updated label files in directory: {input_dir}")

# Specify the input directory containing label files
input_directory = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\labels"

# Run the label processing function
process_labels_in_place(input_directory)
# Out:
# Labels converted and overwritten in C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\labels

# %%
from dataset_utils import random_perspective, augment_hsv, cutout, mixup, load_mosaic
import os
import cv2
import numpy as np
from tqdm import tqdm

def yolo_to_corners(labels):
    """
    Convert YOLO format bounding boxes to corner coordinates.
    """
    new_labels = []
    for label in labels:
        class_id, x_center, y_center, width, height = label
        x_min = x_center - width / 2
        y_min = y_center - height / 2
        x_max = x_center + width / 2
        y_max = y_center + height / 2
        new_labels.append([class_id, x_min, y_min, x_max, y_max])
    return np.array(new_labels)
    

# Function to apply all augmentations to a single image and its labels
def apply_augmentations(image, labels):
    """
    Apply data augmentations from dataset_utils.py to the image and labels.
    """
    
    # Random perspective
    #image, labels = random_perspective(image, labels)
    
    # HSV Augmentation
    image = augment_hsv(image)
    
    # Cutout Augmentation
    image, labels = cutout(image, labels)

    
    
    # Return the augmented image and labels
    return image, labels

# Path to the dataset
images_path = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\images"  # Update with your dataset's train image directory
labels_path = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\train\labels"  # Update with your dataset's train label directory

# Output directories for augmented data
aug_images_path = r"C:\Users\Hp\Downloads\Rice_augmented\Images\train_augmented"
aug_labels_path = r"C:\Users\Hp\Downloads\Rice_augmented\Labels\train_augmented"

# Ensure the output directories exist
os.makedirs(aug_images_path, exist_ok=True)
os.makedirs(aug_labels_path, exist_ok=True)

# Apply augmentations to all training images
print("Applying augmentations to training dataset...")
for img_file in tqdm(os.listdir(images_path)):
    if img_file.endswith('.jpg') or img_file.endswith('.png'):
        # Read the image
        img_path = os.path.join(images_path, img_file)
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
        
        # Read the corresponding label
        label_file = img_file.replace('.jpg', '.txt').replace('.png', '.txt')
        label_path = os.path.join(labels_path, label_file)
        if not os.path.exists(label_path):
            continue
        
        with open(label_path, 'r') as f:
            labels = f.readlines()
        
        # Convert labels to numpy array for augmentation
        labels = np.array([list(map(float, line.strip().split())) for line in labels])
        
        # Apply augmentations
        augmented_image, augmented_labels = apply_augmentations(image, labels)
        
        # Save the augmented image
        aug_img_path = os.path.join(aug_images_path, img_file)
        augmented_image = cv2.cvtColor(augmented_image, cv2.COLOR_RGB2BGR)  # Convert back to BGR
        cv2.imwrite(aug_img_path, augmented_image)
        
        # Save the augmented labels
        aug_label_path = os.path.join(aug_labels_path, label_file)
        with open(aug_label_path, 'w') as f:
            for label in augmented_labels:
                f.write(' '.join(map(str, label)) + '\n')

print("Data augmentation completed. Augmented dataset saved.")

# Create the augmented dataset's YAML file
aug_data_yaml = """
train: C:/Users/Hp/Downloads/Rice_augmented/Images/train_augmented
val: C:/Users/Hp/Downloads/Matrix AI.v1i.yolov8/valid/images
test: C:/Users/Hp/Downloads/Matrix AI.v1i.yolov8/test/images
nc: 5  # Number of classes in your dataset
names: [Arborio, Basmati, Ipsala, Jasmine, Karacadag]  # Class names
train_labels: C:\Users\Hp\Downloads\Rice_augmented\Labels
"""

# Save the new YAML file for augmented data
with open(r"C:\Users\Hp\Downloads\Rice_augmented\data_augmented.yaml", 'w') as f:
    f.write(aug_data_yaml)

print("Updated data.yaml file for augmented dataset created.")
# Out:
# Applying augmentations to training dataset...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 350/350 [00:41<00:00,  8.38it/s]
# Data augmentation completed. Augmented dataset saved.
# Updated data.yaml file for augmented dataset created.

# %%
pip install git+https://github.com/THU-MIG/yolov10.git
# Out:
# Collecting git+https://github.com/THU-MIG/yolov10.git
#   Cloning https://github.com/THU-MIG/yolov10.git to c:\users\hp\appdata\local\temp\pip-req-build-2dix1dr6
#   Resolved https://github.com/THU-MIG/yolov10.git to commit 6fbaf42b23f6709f4e34a51430587673e70e151d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (3.7.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (2.0.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (4.64.1)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (5.9.8)
# Requirement already satisfied: py-cpuinfo in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics==8.1.34) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.12.2)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.2)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics==8.1.34) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.1.34) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.34) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/THU-MIG/yolov10.git 'C:\Users\Hp\AppData\Local\Temp\pip-req-build-2dix1dr6'

# %%
from ultralytics import YOLOv10
import os

# Step 1: Dataset Configuration
aug_data_yaml = r"C:\Users\Hp\Downloads\Rice_augmented\data_augmented.yaml"  # Path to the data.yaml file
assert os.path.exists(aug_data_yaml), "data_augmented.yaml file not found!"

# Step 2: Verify Augmented Dataset Paths
aug_images_path = r"C:\Users\Hp\Downloads\Rice_augmented\Images\train_augmented"
aug_labels_path = r"C:\Users\Hp\Downloads\Rice_augmented\Labels\train_augmented"

assert os.path.exists(aug_images_path), f"Augmented images path not found: {aug_images_path}"
assert os.path.exists(aug_labels_path), f"Augmented labels path not found: {aug_labels_path}"

print("Augmented dataset and configuration verified.")

# Step 3: Load Pretrained YOLOv10-M Model
print("Loading YOLOv10-M pretrained model...")
model = YOLOv10.from_pretrained('jameslahm/yolov10m')

# Step 4: Training Configuration
training_params = {
    "data": aug_data_yaml,  # Use the augmented dataset YAML file
    "epochs": 10,          # Number of epochs for training
    "imgsz": 640,          # Input image size
    "batch": 16,           # Batch size
    "workers": 4,          # Number of workers for data loading
    "device":"cpu"            # Use GPU (set to 0), set to 'cpu' for CPU
}

# Step 5: Start Training
print("Starting training on the augmented dataset...")
model.train(**training_params)

# Step 6: Save the Trained Model
output_model_path = r"C:\Users\Hp\Downloads\yolov10m_augmented.pt"
model.save(output_model_path)
print(f"Training completed. Model saved at: {output_model_path}")

# %%
pip install git+https://github.com/THU-MIG/yolov10.git

# %%
from ultralytics import YOLOv10

model_2= YOLOv10.from_pretrained('jameslahm/yolov10m')

# %%
# Training configuration
training_config = {
    "data": r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\data.yaml",  # Path to the dataset YAML file
    "epochs": 50,           # Number of epochs to train
    "imgsz": 640,           # Input image size
    "batch_size": 16,       # Batch size
    "device": 0,            # Use GPU (0) or CPU (-1)
    "workers": 8,           # Number of data loader workers
    "augment": False        # Disable data augmentation
}

# Train the model
print("Starting training...")
model.train(**training_config)

# Save the trained model
trained_model_path = r"C:\Users\Hp\Downloads\yolov10m_no_augmented.pt"
model.save(trained_model_path)
print(f"Training completed. Model saved at: {trained_model_path}")

# %%
# !pip install ultralytics matplotlib pandas

# %%
from ultralytics import YOLOv10
import matplotlib.pyplot as plt

# Paths to your trained models
model1_path = r"C:\Users\Hp\Downloads\yolov10m_augmented.pt" # Path to the model trained with data augmentation
model2_path = r"C:\Users\Hp\Downloads\yolov10m_no_augmented.pt" # Path to the model trained without data augmentation

# Path to your dataset YAML file
dataset_yaml = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\data.yaml"  # Update with the actual path to your dataset's YAML file

# Evaluation configuration
evaluation_config = {
    "data": dataset_yaml,  # Path to dataset YAML file
    "imgsz": 640,         # Image size
    "conf": 0.25,         # Confidence threshold
    "iou": 0.6            # IoU threshold for evaluation
}

# Initialize models
print("Loading models...")
model1 = YOLOv10(model1_path)  # Model trained with augmentation
model2 = YOLOv10(model2_path)  # Model trained without augmentation

# Evaluate model1 (with augmentation)
print("Evaluating model with data augmentation...")
results_model1 = model1.val(**evaluation_config)

# Evaluate model2 (without augmentation)
print("Evaluating model without data augmentation...")
results_model2 = model2.val(**evaluation_config)

# Extract COCO metrics
coco_metrics = ["mAP@50", "mAP@50:95", "precision", "recall"]

# Performance summary
performance_summary = {
    "Metric": coco_metrics,
    "Model with Augmentation": [
        results_model1["metrics"]["map_50"],
        results_model1["metrics"]["map"],
        results_model1["metrics"]["precision"],
        results_model1["metrics"]["recall"]
    ],
    "Model without Augmentation": [
        results_model2["metrics"]["map_50"],
        results_model2["metrics"]["map"],
        results_model2["metrics"]["precision"],
        results_model2["metrics"]["recall"]
    ]
}

# Display performance summary
import pandas as pd
performance_df = pd.DataFrame(performance_summary)
print("Performance Comparison:")
print(performance_df)

# Visualize performance comparison
plt.figure(figsize=(10, 6))
bar_width = 0.35
x = range(len(coco_metrics))

# Bar chart for comparison
plt.bar(x, performance_summary["Model with Augmentation"], width=bar_width, label="With Augmentation", color="blue")
plt.bar([p + bar_width for p in x], performance_summary["Model without Augmentation"], width=bar_width, label="Without Augmentation", color="orange")

# Add labels and legend
plt.xlabel("Metrics")
plt.ylabel("Values")
plt.title("Performance Comparison: With vs. Without Data Augmentation")
plt.xticks([p + bar_width / 2 for p in x], coco_metrics)
plt.legend()
plt.grid(axis="y")
plt.show()

# %%
# !pip install ultralytics matplotlib

# %%
from ultralytics import YOLOv10
import matplotlib.pyplot as plt
import cv2

# Paths to the trained models
model1_path = r"C:\Users\Hp\Downloads\yolov10m_augmented.pt" # Replace with your model trained on augmented dataset
model2_path = r"C:\Users\Hp\Downloads\yolov10m_no_augmented.pt"  # Replace with your model trained on non-augmented dataset

# Path to the test image
test_image_path = r"C:\Users\Hp\Downloads\Matrix AI.v1i.yolov8\test\images\basmati-78-_jpg.rf.c654422b28b477edcbe42dc12109d3dc.jpg"  # Replace with the path to your test image

# Initialize the models
model1 = YOLOv10(model1_path)  # Model trained with augmentation
model2 = YOLOv10(model2_path)  # Model trained without augmentation

# Run inference with model1 (with augmentation)
results_model1 = model1.predict(source=test_image_path, imgsz=640, conf=0.25)
predicted_image1 = results_model1[0].plot()  # Overlay predictions for model1

# Run inference with model2 (without augmentation)
results_model2 = model2.predict(source=test_image_path, imgsz=640, conf=0.25)
predicted_image2 = results_model2[0].plot()  # Overlay predictions for model2

# Display predictions from both models side by side
plt.figure(figsize=(18, 8))

# Plot model1 predictions
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(predicted_image1, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Model1: Trained with Augmentation")

# Plot model2 predictions
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(predicted_image2, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Model2: Trained without Augmentation")

plt.show()

# %%
# !git clone https://github.com/THU-MIG/yolov10.git

# %%
import os
os.chdir("yolov10")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\Hp\MATRICE NAVYA SINGH\yolov10

# %%
# !pip install git+https://github.com/matrice-ai/matrice-byom.git
